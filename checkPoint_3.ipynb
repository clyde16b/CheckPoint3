# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("titanic-passengers.csv",";")
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %% [raw]
# on a 177 valeurs manquantes pour la variable age, on va remplacé ces valeurs manquantes par la moyenne de l'age.
# aussi pour les variables Cabin et Embarked soit 687 et 2 respectivement mais ces variables sont des string on les laisse comme tels

# %%
data=data.fillna(data["Age"].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %% [raw]
# ici on a remaplacé les valeurs manquantes de l'age par la moyenne d'age, donc la data est prete
# les variables PassengerId,Pclass,Age,SibSp,Parch,Fare sont des variable numérique
# les variables Survived,Name,Sex,Ticket,Cabin,Embarked sont des chaine de caractere

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize=(12,8))
sns.distplot(data['Age'],hist=True,bins=30)
plt.title("Distrubition age")
plt.show()

# %% [raw]
# age moyen des passager de titanic est de 30 ans avec un minimum de moins d'une année et un maximum de 80 ans

# %%
data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data["Survived"].value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(12,20))
plt.subplot(1,3,1)
data["Sex"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Sex")
plt.subplot(1,3,2)
data["Pclass"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Classe des pssager")
plt.subplot(1,3,3)
data["Survived"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Survivant")

plt.show()

# %% [raw]
# Les passagers de Titanic sont majoritairement des hommes avec 64.8%
# aussi la majorité sont de la classe 3
# et seulment 38.4% ont survécu

# %%
pd.crosstab(data["Sex"],data["Survived"],normalize="index")
# Out:
# Survived        No       Yes
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
pd.crosstab(data["Sex"],data["Pclass"],normalize="index")
# Out:
# Pclass         1         2         3
# Sex
# female  0.299363  0.242038  0.458599
# male    0.211438  0.187175  0.601386

# %%
plt.figure()
pd.crosstab(data["Sex"],data["Survived"]).plot.pie(subplots=True,autopct="%1.1f%%",figsize=(12,8),title='Croisement des survivant par sex')
pd.crosstab(data["Survived"],data["Pclass"]).plot.pie(subplots=True,autopct="%1.1f%%",figsize=(15,10),title='Croisement des Classe des passager par sex')
plt.show()

# %% [raw]
# y a plus de survivant femme que d'homme mais cela est du aussi que la majorité des passagers sont des homme
# y a plus de mort chez la classe 3 et 2 que la classe 1

# %%
plt.figure(figsize=(12,8))
x=data[["Fare","Pclass"]].groupby("Pclass").sum()/ data["Fare"].sum()
x.plot.barh()
plt.show()

# %% [markdown]
# les prix des tickets de la classe 1 etait extrement cher 63% de part de marché malgré qu'il y avait que 24.2% de passager de cette classe

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( data )

# %% [raw]
# la diagonal est égale a 1 car chaque élément(variable) est corrélé avec lui meme a 100%
#
# on remarque une forte corrélation entre Parch et SibSp positivement c'est a dire l'augmentation de l'une explique l'augmentation del'autre.
#
# aussi une forte corélation entre Fare et Pclass mais négativement  c'est a dire la diminution de l'une explique l'augmentation de l'autre et vice vers ca
#
# aussi on remarque une corélation négative entre l'age et la Pclass

# %%
data[["Pclass","Survived"]].groupby("Survived").mean()
# Out:
#             Pclass
# Survived
# No        2.531876
# Yes       1.950292

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data2=data.drop(['PassengerId','SibSp','Parch', 'Ticket', 'Cabin', 'Embarked'],axis=1)
data2
# Out:
#     Survived  Pclass                                               Name  \
# 0         No       2                         Collander, Mr. Erik Gustaf
# 1         No       3                            Moen, Mr. Sigurd Hansen
# 2         No       3                             Jensen, Mr. Hans Peder
# 3         No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         No       1                             Davidson, Mr. Thornton
# ..       ...     ...                                                ...
# 886      Yes       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887       No       3                              Sirayanian, Mr. Orsen
# 888       No       3                                Cacic, Miss. Marija
# 889       No       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890      Yes       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
#         Sex        Age     Fare
# 0      male  28.000000  13.0000
# 1      male  25.000000   7.6500
# ...

# %%
l = [name[name.find(',')+2: name.find('.')] for name in data['Name']]
data2['title']=pd.DataFrame(l)
data2
# Out:
#     Survived  Pclass                                               Name  \
# 0         No       2                         Collander, Mr. Erik Gustaf
# 1         No       3                            Moen, Mr. Sigurd Hansen
# 2         No       3                             Jensen, Mr. Hans Peder
# 3         No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         No       1                             Davidson, Mr. Thornton
# ..       ...     ...                                                ...
# 886      Yes       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887       No       3                              Sirayanian, Mr. Orsen
# 888       No       3                                Cacic, Miss. Marija
# 889       No       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890      Yes       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
#         Sex        Age     Fare title
# 0      male  28.000000  13.0000    Mr
# ...

# %%
pd.crosstab(data2["title"],data2["Sex"])
# Out:
# Sex           female  male
# title
# Capt               0     1
# Col                0     2
# Don                0     1
# Dr                 1     6
# Jonkheer           0     1
# Lady               1     0
# Major              0     2
# Master             0    40
# Miss             182     0
# Mlle               2     0
# Mme                1     0
# Mr                 0   517
# Mrs              125     0
# Ms                 1     0
# Rev                0     6
# Sir                0     1
# the Countess       1     0

# %%
pd.crosstab(data2["title"],data2["Pclass"])
# Out:
# Pclass          1   2    3
# title
# Capt            1   0    0
# Col             2   0    0
# Don             1   0    0
# Dr              5   2    0
# Jonkheer        1   0    0
# Lady            1   0    0
# Major           2   0    0
# Master          3   9   28
# Miss           46  34  102
# Mlle            2   0    0
# Mme             1   0    0
# Mr            107  91  319
# Mrs            42  41   42
# Ms              0   1    0
# Rev             0   6    0
# Sir             1   0    0
# the Countess    1   0    0

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
data2['Statut'] = data2['title'].map(Title_Dictionary) 

data2
# Out:
#     Survived  Pclass                                               Name  \
# 0         No       2                         Collander, Mr. Erik Gustaf
# 1         No       3                            Moen, Mr. Sigurd Hansen
# 2         No       3                             Jensen, Mr. Hans Peder
# 3         No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         No       1                             Davidson, Mr. Thornton
# ..       ...     ...                                                ...
# 886      Yes       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887       No       3                              Sirayanian, Mr. Orsen
# 888       No       3                                Cacic, Miss. Marija
# 889       No       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890      Yes       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
#         Sex        Age     Fare title Statut
# 0      male  28.000000  13.0000    Mr    Mrs
# ...

# %%
plt.figure(figsize=(12,8))
data2['Statut'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
data["familysize"]=data["Parch"]+data["SibSp"]
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
data["familysize"].value_counts()
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: familysize, dtype: int64
